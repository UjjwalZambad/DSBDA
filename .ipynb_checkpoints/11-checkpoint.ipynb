# %%
import requests
import bs4

# %%
request1=requests.get('https://www.flipkart.com/beardo-beard-hair-growth-oil-50-ml-oil-men-faster-thicker-fuller-looking-best-patchy-clinically-tested-non-sticky/p/itmc21cc128d5ae4?pid=HOLFMSBGMYPGBGFR&lid=LSTHOLFMSBGMYPGBGFRQ9Z2LW&marketplace=FLIPKART&store=g9b&srno=b_1_5&otracker=nmenu_sub_Men_0_Beard%20Care%20%26%20Grooming&fm=organic&iid=dcd0af1b-1b76-4329-8fed-c19c25f91f87.HOLFMSBGMYPGBGFR.SEARCH&ppt=browse&ppn=browse&ssid=w553qo40m80000001714931076189')
request1
# Out:
# <Response [200]>

# %%
request1.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.47c551.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
soup=bs4.BeautifulSoup(request1.text)

# %%
avg_ratings = soup.find('div',{'class':'XQDdHH'}).get_text()
avg_ratings
# Out:
# '4'

# %%
reviews=soup.find_all('div',{'class':'_11pzQk'})
for review in reviews:
    print(review.get_text() + '\n')
# Out:
# Beard growth depends on hormones. This oil only helps in nourishing your beard and can increase the growth by 10-20% only when you were getting little beard before also....Don't expect any magic from this oil like they show in ads....
#
# I didn't have much beard.After using it for 1 week there is so much improvement to my patchy beard.Advice : Wash your face before use.
#
# best and genuine product.. It really works well. I loved it.

# %%
customer_names=soup.find_all('p',{'class':'_2NsDsF AwS1CA MDcJkH'});
for customer_name in customer_names:
    print(customer_name.get_text() + '\n')
# Out:
# Vinay gupta
#
# Ajay Bhatt
#
# chandu Reddy

# %%
individual_ratings= soup.find_all('div',{'class':'XQDdHH Ga3i8K _9lBNRY'})
for ind_rating in individual_ratings:
    print(ind_rating.get_text()+"\n")
# Out:
# 4
#
# 5
#
# 5
